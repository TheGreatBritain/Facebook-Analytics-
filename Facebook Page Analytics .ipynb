# %% [markdown]
# # Insights from Facebook Page's data

# %% [markdown]
# ## Step 1 - Load data
#
# Upload .csv files

# %%
# Libaries area
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import datetime

# Set configuration to display all columns in Jupyter Notebook
pd.set_option('display.max_columns', None)

# Function for read FB's exported file. It always has column description at the 2nd row.
def readFBfile(fb_filename):
    # Read the file
    df_tmp = pd.read_csv(fb_filename)
    global df
    df = pd.DataFrame([])
    # Remove the second row, as it is column description and won't be used
    df_tmp.drop(axis=1,index=0,inplace=True)
    return df_tmp

# %%
import os
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn import metrics
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt   #Data visualisation libraries 
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
import statsmodels.api as sm
#import plotly
#import plotly.graph_objs as go
#plotly.offline.init_notebook_mode()
from mpl_toolkits.mplot3d import Axes3D

# %%
df_cpm = pd.read_csv('/Users/btaylor7/Downloads/Facebook_Insights_Data_Export_Post_Level_-_Indiana_Alzheimer_s_Disease_Research_Center_-_2020-09-10 Post Data.csv')
df_cpm = pd.read_csv('/Users/btaylor7/Downloads/Facebook_Insights_Data_Export_-_Indiana_Alzheimer_s_Disease_Research_Center_-_2020-09-10 Page Data.csv')

# %%
df_cpm.head()
# Out:
#          Date                               Lifetime Total Likes  \
# 0         NaN  Lifetime: The total number of people who have ...
# 1  2020-08-01                                                554
# 2  2020-08-02                                                557
# 3  2020-08-03                                                557
# 4  2020-08-04                                                557
#
#                                      Daily New Likes  \
# 0  Daily: The number of new people who have liked...
# 1                                                  4
# 2                                                  3
# 3                                                NaN
# 4                                                NaN
#
#                                        Daily Unlikes  \
# 0  Daily: The number of Unlikes of your Page (Uni...
# 1                                                  1
# 2                                                NaN
# ...

# %%
# Read the exported data which is in CSV data
df1 = readFBfile('/Users/btaylor7/Downloads/Facebook_Insights_Data_Export_Post_Level_-_Indiana_Alzheimer_s_Disease_Research_Center_-_2020-09-10 Post Data.csv')
df2 = readFBfile('/Users/btaylor7/Downloads/Facebook_Insights_Data_Export_-_Indiana_Alzheimer_s_Disease_Research_Center_-_2020-09-10 Page Data.csv')
#df3 = readFBfile('2019-3.csv')
#df4 = readFBfile('2018-1.csv')
#df5 = readFBfile('2018-2.csv')
#df6 = readFBfile('2018-3.csv')

# Quickly check the number of row, the list of columns and its type
df1.info()
df2.info()
#df3.info()
#df4.info()
#df5.info()
#df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 1 to 13
# Data columns (total 50 columns):
#  #   Column                                                                       Non-Null Count  Dtype
# ---  ------                                                                       --------------  -----
#  0   Post ID                                                                      13 non-null     object
#  1   Permalink                                                                    13 non-null     object
#  2   Post Message                                                                 11 non-null     object
#  3   Type                                                                         13 non-null     object
#  4   Countries                                                                    0 non-null      float64
#  5   Languages                                                                    0 non-null      float64
# ...

# %% [markdown]
# Columns appended to be one dataframe and explore the data type and null value further.

# %% [markdown]
# ### 2.2 Page level data
#
# For page level data, we have just only 180 days backward from today per facebook's limitaion.

# %%
df_page = readFBfile('/Users/btaylor7/Downloads/Facebook_Insights_Data_Export_Post_Level_-_Indiana_Alzheimer_s_Disease_Research_Center_-_2020-09-10 Post Data.csv')
df_page = readFBfile('/Users/btaylor7/Downloads/Facebook_Insights_Data_Export_-_Indiana_Alzheimer_s_Disease_Research_Center_-_2020-09-10 Page Data.csv')
# Drop the first row as it is the column's description
df_page.info()
df_page.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 1 to 31
# Columns: 1482 entries, Date to Weekly Total web site click count per Page by age and gender - UNKNOWN.U
# dtypes: float64(1280), object(202)
# memory usage: 359.2+ KB
# Date                                                                         0
# Lifetime Total Likes                                                         0
# Daily New Likes                                                              4
# Daily Unlikes                                                               25
# Daily Page Engaged Users                                                     0
#                                                                             ..
# Weekly Total web site click count per Page by age and gender - &lt;13.M      0
# Weekly Total web site click count per Page by age and gender - &lt;13.U      0
# Weekly Total web site click count per Page by age and gender - UNKNOWN.F     0
# ...

# %%
# Check example of data - use transpose for easier check the column
np.transpose(df_page.head())
# Out:
#                                                              1           2  \
# Date                                                2020-08-01  2020-08-02
# Lifetime Total Likes                                       554         557
# Daily New Likes                                              4           3
# Daily Unlikes                                                1         NaN
# Daily Page Engaged Users                                    14          11
# ...                                                        ...         ...
# Weekly Total web site click count per Page by a...           0           0
# Weekly Total web site click count per Page by a...           0           0
# Weekly Total web site click count per Page by a...           0           0
# Weekly Total web site click count per Page by a...           0           0
# Weekly Total web site click count per Page by a...           0           0
#
# ...

# %% [markdown]
# In summary, the approximated factors value that influence page like are:
#
# 1. Like         : 38 - 1,000
# 2. Share        : 1  - 40
# 3. Other Clicks : 77 - 2,000
# 4. Impression   : 0  - 40,000
# 5. Reach        : 0  - 25,000
#
# These number can be used as base line to measure and guide the quality of content. The more close or exceed the upper bound is the better.
